# %%
from search_run.ranking import Ranking


df = Ranking().load_dataset()


df
# Out:
# Line broken: {"key": "grimoire api start via tmux", "generated_date": "2021-01-25 19:41:50"}
#
# Line broken: {"generated_date": "2021-04-29 11:43:29", "uuid": "3a61ebe6-b39d-4ab2-9c5c-9d908a52d5a3", "key": "grimoire api start via tmux"}
#
# Line broken: {"generated_date": "2021-06-05 00:51:26", "uuid": "54e029d1-2490-4b35-86b4-cc7a63478d58", "key": "start search run dmenu"}
#                                        key       generated_date  \
# 114937                  main browser focus  2021-08-22 15:07:00
# 114936               random terminal focus  2021-08-22 15:05:54
# 114935               random terminal focus  2021-08-22 15:05:30
# 114934  ide for project search run library  2021-08-22 14:56:49
# 114933              start search run dmenu  2021-08-22 14:56:43
# ...                                    ...                  ...
# 4                   start search run dmenu  2021-01-03 16:52:19
# 3            search run edit configuration  2021-01-03 16:52:00
# ...
